# %%
import pandas as pd #Pandas is a powerful and popular Python library used for data manipulation and analysis.
import numpy as np #numpy is a python library and provides support for large multiple dimensional array and matrix
import matplotlib.pyplot as plt #matplotlib is used for creating statical,interactive visualizations
import seaborn as sns#Seaborn is particularly useful for visualizing complex datasets and generating visually appealing plots with minimal code

# %% [markdown]
# # **Introduction:**
#
# Weather data plays a crucial role in our daily lives and various industries, from agriculture to transportation and emergency preparedness. Understanding and effectively utilizing weather data can help individuals and organizations make informed decisions, improve safety, and optimize operations.
#
# Types of Weather Data:
# Weather data encompasses a wide range of information collected from various sources, including meteorological stations, satellites, weather balloons, and weather radars. The key types of weather data include:
#
# a. Temperature: Information about the current and forecasted temperature, which impacts clothing choices, heating and cooling needs, and agricultural practices.
#
# b. Precipitation: Data on rainfall, snowfall, and other forms of precipitation, critical for water resource management, flood forecasting, and agricultural planning.
#
# c. Humidity: Measures the amount of moisture in the air, influencing human comfort, crop health, and weather patterns.
#
# d. Wind Speed and Direction: Wind data is vital for aviation, renewable energy generation, and understanding weather patterns.
#
# e. Atmospheric Pressure: Information about the pressure exerted by the atmosphere, useful for weather predictions and altimeter settings for aviation.
#
# f. Cloud Cover: Indicates the fraction of the sky covered by clouds and helps determine potential rainfall and solar radiation.
#
# g. UV Index: Measures the strength of ultraviolet radiation from the sun, important for skin protection and outdoor activities.
#
# Weather Data Sources:
# Weather data comes from a variety of sources, including:
#
# a. National Meteorological Agencies: Government agencies responsible for collecting and disseminating weather information for specific regions or countries.
#
# b. Weather Stations: Ground-based installations that monitor local weather conditions, including temperature, humidity, and precipitation.
#
# c. Satellites: Orbiting satellites capture images and data from space, providing a broader perspective on weather patterns and storms.
#
# d. Weather Radars: Used to detect precipitation, measure wind speed, and identify severe weather events such as tornadoes and thunderstorms.
#
# e. Weather Balloons: Instruments attached to weather balloons collect atmospheric data at different altitudes.
#
# f. Weather Apps and Websites: Online platforms that provide real-time weather updates and forecasts based on data from various sources.
#
# Applications of Weather Data:
# Weather data has numerous applications across various industries and activities, including:
#
# a. Agriculture: Farmers use weather data to schedule irrigation, plan planting and harvesting, and mitigate the impact of extreme weather on crops.
#
# b. Transportation: Airlines, shipping companies, and road networks rely on weather data to optimize routes, avoid hazardous conditions, and ensure passenger safety.
#
# c. Renewable Energy: Wind and solar energy generation depend on weather data to predict energy production and manage power grids efficiently.
#
# d. Disaster Preparedness: Weather data is vital for early warning systems and emergency response planning during hurricanes, floods, and other severe weather events.
#
# e. Tourism: Tour operators and travelers use weather forecasts to plan outdoor activities and make the most of their trips.
#
# Challenges in Weather Data Analysis:
# While weather data is invaluable, analyzing and interpreting it can be complex due to:
#
# a. Data Volume: Weather data is vast and constantly updating, requiring powerful computing systems for processing and analysis.
#
# b. Data Quality: Ensuring the accuracy and reliability of weather data is crucial, as errors can lead to significant consequences.
#
# c. Forecasting Accuracy: Weather forecasting involves uncertainties, and improving prediction accuracy is an ongoing challenge for meteorologists.

# %%
df=pd.read_csv("Weather__Data.csv")
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind_Speed_km  \
# 0     01-01-2012 00:00    -1.8              -3.9         86              4
# 1     01-01-2012 01:00    -1.8              -3.7         87              4
# 2     01-01-2012 02:00    -1.8              -3.4         89              7
# 3     01-01-2012 03:00    -1.5              -3.2         88              6
# 4     01-01-2012 04:00    -1.5              -3.3         88              7
# ...                ...     ...               ...        ...            ...
# 8779  12/31/2012 19:00     0.1              -2.7         81             30
# 8780  12/31/2012 20:00     0.2              -2.4         83             24
# 8781  12/31/2012 21:00    -0.5              -1.5         93             28
# 8782  12/31/2012 22:00    -0.2              -1.8         89             28
# 8783  12/31/2012 23:00     0.0              -2.1         86             30
#
#       Visibility_km  Press_kPa               Weather
# 0               8.0     101.24                   Fog
# 1               8.0     101.24                   Fog
# 2               4.0     101.26  Freezing Drizzle,Fog
# 3               4.0     101.27  Freezing Drizzle,Fog
# 4               4.8     101.23                   Fog
# ...             ...        ...                   ...
# 8779            9.7     100.13                  Snow
# 8780            9.7     100.03                  Snow
# 8781            4.8      99.95                  Snow
# 8782            9.7      99.91                  Snow
# 8783           11.3      99.89                  Snow
#
# [8784 rows x 8 columns]

# %%
df.head() #head() it is used to display the top few rows of dataframe or series.
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind_Speed_km  \
# 0  01-01-2012 00:00    -1.8              -3.9         86              4
# 1  01-01-2012 01:00    -1.8              -3.7         87              4
# 2  01-01-2012 02:00    -1.8              -3.4         89              7
# 3  01-01-2012 03:00    -1.5              -3.2         88              6
# 4  01-01-2012 04:00    -1.5              -3.3         88              7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
df.info() #it provieds essential information about dataframe
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind_Speed_km     8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind_Speed_km  \
# 0     01-01-2012 00:00    -1.8              -3.9         86              4
# 1     01-01-2012 01:00    -1.8              -3.7         87              4
# 2     01-01-2012 02:00    -1.8              -3.4         89              7
# 3     01-01-2012 03:00    -1.5              -3.2         88              6
# 4     01-01-2012 04:00    -1.5              -3.3         88              7
# ...                ...     ...               ...        ...            ...
# 8779  12/31/2012 19:00     0.1              -2.7         81             30
# 8780  12/31/2012 20:00     0.2              -2.4         83             24
# 8781  12/31/2012 21:00    -0.5              -1.5         93             28
# 8782  12/31/2012 22:00    -0.2              -1.8         89             28
# 8783  12/31/2012 23:00     0.0              -2.1         86             30
#
#       Visibility_km  Press_kPa               Weather
# 0               8.0     101.24                   Fog
# 1               8.0     101.24                   Fog
# 2               4.0     101.26  Freezing Drizzle,Fog
# 3               4.0     101.27  Freezing Drizzle,Fog
# 4               4.8     101.23                   Fog
# ...             ...        ...                   ...
# 8779            9.7     100.13                  Snow
# 8780            9.7     100.03                  Snow
# 8781            4.8      99.95                  Snow
# 8782            9.7      99.91                  Snow
# 8783           11.3      99.89                  Snow
#
# [8784 rows x 8 columns]

# %%
df.describe() #it is used to display the bottom few rows of dataframe or series
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind_Speed_km  \
# 0     01-01-2012 00:00    -1.8              -3.9         86              4
# 1     01-01-2012 01:00    -1.8              -3.7         87              4
# 2     01-01-2012 02:00    -1.8              -3.4         89              7
# 3     01-01-2012 03:00    -1.5              -3.2         88              6
# 4     01-01-2012 04:00    -1.5              -3.3         88              7
# ...                ...     ...               ...        ...            ...
# 8779  12/31/2012 19:00     0.1              -2.7         81             30
# 8780  12/31/2012 20:00     0.2              -2.4         83             24
# 8781  12/31/2012 21:00    -0.5              -1.5         93             28
# 8782  12/31/2012 22:00    -0.2              -1.8         89             28
# 8783  12/31/2012 23:00     0.0              -2.1         86             30
#
#       Visibility_km  Press_kPa               Weather
# 0               8.0     101.24                   Fog
# 1               8.0     101.24                   Fog
# 2               4.0     101.26  Freezing Drizzle,Fog
# 3               4.0     101.27  Freezing Drizzle,Fog
# 4               4.8     101.23                   Fog
# ...             ...        ...                   ...
# 8779            9.7     100.13                  Snow
# 8780            9.7     100.03                  Snow
# 8781            4.8      99.95                  Snow
# 8782            9.7      99.91                  Snow
# 8783           11.3      99.89                  Snow
#
# [8784 rows x 8 columns]

# %%
print("The shape of the dataset is:", df.shape)
print("The columns in the dataset are:", df.columns)
print("The data types of the columns are:\n", df.dtypes)
# Out:
# The shape of the dataset is: (8784, 8)
# The columns in the dataset are: Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%', 'Wind_Speed_km',
#        'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')
# The data types of the columns are:
#  Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind_Speed_km         int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
# Visualization
sns.scatterplot(x="Temp_C", y="Dew Point Temp_C", data=df)
plt.show()

# %%
sns.countplot(x="Weather", data=df) #its easy to find the levels easily by seeing the colours representing each of the following.
plt.show()

# %%
df.hist(figsize=(12, 10))
plt.suptitle('Histograms of Features', fontsize=16)
plt.show()

# %%
sns.heatmap(df.corr(), annot=True)
plt.show()
# Out:
# <ipython-input-8-6522c2b4e5f9>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind_Speed_km     8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
#Missing values
print("The number of missing values in each column is:\n", df.isnull().sum())
# Out:
# The number of missing values in each column is:
#  Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind_Speed_km       0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
 #Outliers
sns.boxplot(x="Temp_C", data=df)
plt.show()

# %%
sns.boxplot(x="Dew Point Temp_C", data=df)
plt.show()

# %%
sns.boxplot(x="Rel Hum_%", data=df)
plt.show()

# %%
sns.boxplot(x="Wind_Speed_km", data=df)
plt.show()

# %%
sns.boxplot(x="Visibility_km", data=df)
plt.show()

# %%
sns.boxplot(x="Press_kPa", data=df)
plt.show()

# %%
# Skewness
print("The skewness of each column is:\n", df.skew())
# Out:
# The skewness of each column is:
#  Temp_C             -0.177666
# Dew Point Temp_C   -0.318433
# Rel Hum_%          -0.323830
# Wind_Speed_km       0.871374
# Visibility_km       0.413362
# Press_kPa          -0.229925
# dtype: float64
# <ipython-input-19-8f959788cbef>:2: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print("The skewness of each column is:\n", df.skew())

# %%
# Preprocessing
df = pd.get_dummies(df, columns=["Weather"], prefix=["Weather"])
df = (df - df.mean()) / df.std()
# Out:
# <ipython-input-20-051694f9f6b4>:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df = (df - df.mean()) / df.std()
# <ipython-input-20-051694f9f6b4>:3: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df = (df - df.mean()) / df.std()

# %%
# Model fitting and prediction
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X = df.drop(["Date/Time"], axis=1)
y = df["Temp_C"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train
# Out:
#       Dew Point Temp_C  Press_kPa  Rel Hum_%    Temp_C  Visibility_km  \
# 8372         -0.666659   0.945939  -0.025516 -0.684311      -0.211084
# 349          -2.458432   1.893800  -0.852993 -2.190144       1.634799
# 5743          1.318075   0.365373   0.033590  1.223648      -0.282384
# 6103          0.537046   0.993332   0.979279  0.188388       1.634799
# 8581         -1.374179  -0.807606  -0.025516 -1.385892      -0.282384
# ...                ...        ...        ...       ...            ...
# 4174          0.840269  -0.677275  -0.734782  1.052531      -0.211084
# 5988          1.354829  -0.712820  -0.675677  1.540215      -0.282384
# 197          -1.401745   1.040725   0.210907 -1.471451      -0.211084
# 400          -0.786110  -1.613289   0.920173 -1.052213      -2.096578
# 7076          0.270577  -0.499551  -0.025516  0.222611      -0.211084
#
#       Weather_Clear  Weather_Cloudy  Weather_Drizzle  Weather_Drizzle,Fog  \
# 8372      -0.421634       -0.494843        -0.068476            -0.095865
# 349       -0.421634       -0.494843        -0.068476            -0.095865
# 5743      -0.421634       -0.494843        -0.068476            -0.095865
# 6103      -0.421634       -0.494843        -0.068476            -0.095865
# 8581      -0.421634       -0.494843        -0.068476            -0.095865
# ...             ...             ...              ...                  ...
# 4174      -0.421634       -0.494843        -0.068476            -0.095865
# 5988      -0.421634       -0.494843        -0.068476            -0.095865
# 197       -0.421634        2.020611        -0.068476            -0.095865
# 400       -0.421634       -0.494843        -0.068476            -0.095865
# 7076      -0.421634       -0.494843        -0.068476            -0.095865
#
#       Weather_Drizzle,Ice Pellets,Fog  ...  Weather_Snow,Haze  \
# 8372                         -0.01067  ...          -0.023864
# 349                          -0.01067  ...          -0.023864
# 5743                         -0.01067  ...          -0.023864
# 6103                         -0.01067  ...          -0.023864
# 8581                         -0.01067  ...          -0.023864
# ...                               ...  ...                ...
# 4174                         -0.01067  ...          -0.023864
# 5988                         -0.01067  ...          -0.023864
# 197                          -0.01067  ...          -0.023864
# 400                          -0.01067  ...          -0.023864
# 7076                         -0.01067  ...          -0.023864
#
#       Weather_Snow,Ice Pellets  Weather_Thunderstorms  \
# 8372                 -0.026143               -0.01509
# 349                  -0.026143               -0.01509
# 5743                 -0.026143               -0.01509
# 6103                 -0.026143               -0.01509
# 8581                 -0.026143               -0.01509
# ...                        ...                    ...
# 4174                 -0.026143               -0.01509
# 5988                 -0.026143               -0.01509
# 197                  -0.026143               -0.01509
# 400                  -0.026143               -0.01509
# 7076                 -0.026143               -0.01509
#
#       Weather_Thunderstorms,Heavy Rain Showers  \
# 8372                                  -0.01067
# 349                                   -0.01067
# 5743                                  -0.01067
# 6103                                  -0.01067
# 8581                                  -0.01067
# ...                                        ...
# 4174                                  -0.01067
# 5988                                  -0.01067
# 197                                   -0.01067
# 400                                   -0.01067
# 7076                                  -0.01067
#
#       Weather_Thunderstorms,Moderate Rain Showers,Fog  \
# 8372                                         -0.01067
# 349                                          -0.01067
# 5743                                         -0.01067
# 6103                                         -0.01067
# 8581                                         -0.01067
# ...                                               ...
# 4174                                         -0.01067
# 5988                                         -0.01067
# 197                                          -0.01067
# 400                                          -0.01067
# 7076                                         -0.01067
#
#       Weather_Thunderstorms,Rain  Weather_Thunderstorms,Rain Showers  \
# 8372                   -0.018483                           -0.042715
# 349                    -0.018483                           -0.042715
# 5743                   -0.018483                           -0.042715
# 6103                   -0.018483                           -0.042715
# 8581                   -0.018483                           -0.042715
# ...                          ...                                 ...
# 4174                   -0.018483                           -0.042715
# 5988                   -0.018483                           -0.042715
# 197                    -0.018483                           -0.042715
# 400                    -0.018483                           -0.042715
# 7076                   -0.018483                           -0.042715
#
#       Weather_Thunderstorms,Rain Showers,Fog  Weather_Thunderstorms,Rain,Fog  \
# 8372                               -0.018483                        -0.01067
# 349                                -0.018483                        -0.01067
# 5743                               -0.018483                        -0.01067
# 6103                               -0.018483                        -0.01067
# 8581                               -0.018483                        -0.01067
# ...                                      ...                             ...
# 4174                               -0.018483                        -0.01067
# 5988                               -0.018483                        -0.01067
# 197                                -0.018483                        -0.01067
# 400                                -0.018483                        -0.01067
# 7076                               -0.018483                        -0.01067
#
#       Wind_Speed_km
# 8372       0.006276
# 349        0.581736
# 5743      -0.223908
# 6103      -0.684276
# 8581       0.581736
# ...             ...
# 4174      -0.684276
# 5988       0.006276
# 197       -0.454092
# 400        1.502473
# 7076       0.581736
#
# [6148 rows x 56 columns]

# %%
X_test
# Out:
#       Dew Point Temp_C  Press_kPa  Rel Hum_%    Temp_C  Visibility_km  \
# 1698         -0.326681   0.744518  -1.089416  0.025826      -0.211084
# 7348         -0.005081  -1.885799   1.097490 -0.350632      -0.211084
# 6137          0.831080   0.851152  -1.680471  1.540215       1.634799
# 2534          0.693252  -0.440310  -0.734782  0.907081      -0.282384
# 4524          1.281321  -0.748365  -0.793888  1.514548      -0.282384
# ...                ...        ...        ...       ...            ...
# 5540          0.491103  -0.203344  -1.030310  0.838634      -0.211084
# 4522          1.235378  -0.736516  -0.380149  1.309207      -0.282384
# 2109         -0.280738  -1.340778   1.333912 -0.667199      -1.423187
# 5258          1.125115  -0.073013   0.565540  0.864302      -0.211084
# 6430          0.279765   0.033621  -0.321043  0.325282      -0.211084
#
#       Weather_Clear  Weather_Cloudy  Weather_Drizzle  Weather_Drizzle,Fog  \
# 1698       2.371454       -0.494843        -0.068476            -0.095865
# 7348      -0.421634        2.020611        -0.068476            -0.095865
# 6137      -0.421634       -0.494843        -0.068476            -0.095865
# 2534      -0.421634       -0.494843        -0.068476            -0.095865
# 4524      -0.421634       -0.494843        -0.068476            -0.095865
# ...             ...             ...              ...                  ...
# 5540       2.371454       -0.494843        -0.068476            -0.095865
# 4522      -0.421634       -0.494843        -0.068476            -0.095865
# 2109      -0.421634       -0.494843        -0.068476            -0.095865
# 5258       2.371454       -0.494843        -0.068476            -0.095865
# 6430      -0.421634       -0.494843        -0.068476            -0.095865
#
#       Weather_Drizzle,Ice Pellets,Fog  ...  Weather_Snow,Haze  \
# 1698                         -0.01067  ...          -0.023864
# 7348                         -0.01067  ...          -0.023864
# 6137                         -0.01067  ...          -0.023864
# 2534                         -0.01067  ...          -0.023864
# 4524                         -0.01067  ...          -0.023864
# ...                               ...  ...                ...
# 5540                         -0.01067  ...          -0.023864
# 4522                         -0.01067  ...          -0.023864
# 2109                         -0.01067  ...          -0.023864
# 5258                         -0.01067  ...          -0.023864
# 6430                         -0.01067  ...          -0.023864
#
#       Weather_Snow,Ice Pellets  Weather_Thunderstorms  \
# 1698                 -0.026143               -0.01509
# 7348                 -0.026143               -0.01509
# 6137                 -0.026143               -0.01509
# 2534                 -0.026143               -0.01509
# 4524                 -0.026143               -0.01509
# ...                        ...                    ...
# 5540                 -0.026143               -0.01509
# 4522                 -0.026143               -0.01509
# 2109                 -0.026143               -0.01509
# 5258                 -0.026143               -0.01509
# 6430                 -0.026143               -0.01509
#
#       Weather_Thunderstorms,Heavy Rain Showers  \
# 1698                                  -0.01067
# 7348                                  -0.01067
# 6137                                  -0.01067
# 2534                                  -0.01067
# 4524                                  -0.01067
# ...                                        ...
# 5540                                  -0.01067
# 4522                                  -0.01067
# 2109                                  -0.01067
# 5258                                  -0.01067
# 6430                                  -0.01067
#
#       Weather_Thunderstorms,Moderate Rain Showers,Fog  \
# 1698                                         -0.01067
# 7348                                         -0.01067
# 6137                                         -0.01067
# 2534                                         -0.01067
# 4524                                         -0.01067
# ...                                               ...
# 5540                                         -0.01067
# 4522                                         -0.01067
# 2109                                         -0.01067
# 5258                                         -0.01067
# 6430                                         -0.01067
#
#       Weather_Thunderstorms,Rain  Weather_Thunderstorms,Rain Showers  \
# 1698                   -0.018483                           -0.042715
# 7348                   -0.018483                           -0.042715
# 6137                   -0.018483                           -0.042715
# 2534                   -0.018483                           -0.042715
# 4524                   -0.018483                           -0.042715
# ...                          ...                                 ...
# 5540                   -0.018483                           -0.042715
# 4522                   -0.018483                           -0.042715
# 2109                   -0.018483                           -0.042715
# 5258                   -0.018483                           -0.042715
# 6430                   -0.018483                           -0.042715
#
#       Weather_Thunderstorms,Rain Showers,Fog  Weather_Thunderstorms,Rain,Fog  \
# 1698                               -0.018483                        -0.01067
# 7348                               -0.018483                        -0.01067
# 6137                               -0.018483                        -0.01067
# 2534                               -0.018483                        -0.01067
# 4524                               -0.018483                        -0.01067
# ...                                      ...                             ...
# 5540                               -0.018483                        -0.01067
# 4522                               -0.018483                        -0.01067
# 2109                               -0.018483                        -0.01067
# 5258                               -0.018483                        -0.01067
# 6430                               -0.018483                        -0.01067
#
#       Wind_Speed_km
# 1698      -0.914460
# 7348       0.581736
# 6137       0.236460
# 2534       1.272289
# 4524       0.811921
# ...             ...
# 5540      -0.914460
# 4522       0.466644
# 2109       0.006276
# 5258       0.466644
# 6430       0.236460
#
# [2636 rows x 56 columns]

# %%
y_test
# Out:
# 1698    0.025826
# 7348   -0.350632
# 6137    1.540215
# 2534    0.907081
# 4524    1.514548
#           ...
# 5540    0.838634
# 4522    1.309207
# 2109   -0.667199
# 5258    0.864302
# 6430    0.325282
# Name: Temp_C, Length: 2636, dtype: float64

# %%
y_train
# Out:
# 8372   -0.684311
# 349    -2.190144
# 5743    1.223648
# 6103    0.188388
# 8581   -1.385892
#           ...
# 4174    1.052531
# 5988    1.540215
# 197    -1.471451
# 400    -1.052213
# 7076    0.222611
# Name: Temp_C, Length: 6148, dtype: float64

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
# Model evaluation
from sklearn.metrics import mean_squared_error, r2_score

# %%
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, y_pred))
# Out:
# Mean squared error: 0.00

# %%
print('Coefficient of determination: %.2f'
      % r2_score(y_test, y_pred))
# Out:
# Coefficient of determination: 1.00

# %%
print("Accuracy score:", model.score(X_test, y_test))
# Out:
# Accuracy score: 0.9999999877292031

# %% [markdown]
# To predict weather we have to take so many inputs according to  the weather conditions
